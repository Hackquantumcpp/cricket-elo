# %%
import numpy as np
import pandas as pd
import scipy
import scipy.optimize as opt
import json
import os
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from sklearn.feature_selection import r_regression

from espncricinfo.match import Match

from tqdm import tqdm

# %%
#!pip3 install python-espncricinfo

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# df_afg = scrape_afghanistan_t20is()
# df_afg.head()

# %%
# data = pd.read_csv('cricket_matches.csv')
# data

# %%
# teams = np.unique(np.append(data['team1'].values, data['team2'].values))
# teams

# %%
# data.columns.values

# %%
def prob_win_A(R_a: float, R_b: float, alpha: float = 400, home: str = 'neutral', hga: float = 0):
    if home == 'neutral':
        E_a = 1 / (1 + 10**( (R_b - R_a) / alpha ))
    elif home == 'first':
        E_a = 1 / (1 + 10**( (R_b - (R_a + hga) ) / alpha ))
    elif home == 'second':
        E_a = E_a = 1 / (1 + 10**( (R_b + hga - R_a) / alpha ))
    else:
        raise ValueError('Not a valid home country')
    return E_a

def elo_step(R_a: float, R_b: float, S: float, K: float, W_mv: float, alpha: float, home: str = 'neutral', hga: float = 0):
    E_a = prob_win_A(R_a, R_b, alpha, home, hga)
    E_b = 1 - E_a
    R_a_pr = R_a + K*(S - E_a)*W_mv
    R_b_pr = R_b + K*((1-S) - E_b)*W_mv
    
    return R_a_pr, R_b_pr

# %%
def prob_win_country_A(team_elos, country_A: str, country_B: str, venue_country: str, alpha: float = 400, hga: float = 0):
    """
    :param team_elos: Dictionary of elo ratings for each team.
    For the purposes of this function, country_A is the country for which win probability is calculated.
    """
    R_a = team_elos[country_A]
    R_b = team_elos[country_B]
    if venue_country == country_A:
        home = 'first'
    elif venue_country == country_B:
        home = 'second'
    else:
        home = 'neutral'
    return prob_win_A(R_a, R_b, alpha, home, hga)

# %%
def calculate_W_mv_m1(nrr):
    """
    :param nrr: Net run rate for game.
    """
    return (3 + nrr)**0.63 - 1 # Testing this out

def calculate_W_mv_log(nrr, elodiff):
    """
    :param nrr: Net run rate for game
    :param elodiff: Elo rating difference. ELODIFF = ELOW - ELOL
    """
    return np.log(1 + abs(min(nrr, 3))) * 2.2/(0.001*elodiff + 2.2) # Testing this out

# %%
def generate_elo_ratings(data, teams, K, alpha=400, calculate_W_mv=calculate_W_mv_log, hga=0, mean_rev_const=0.3):
    """
    :param data: DataFrame of games played.
    :param teams: Dictionary of all teams with respective elo rating scores. At the start, all teams' Elo ratings 
    will be set to 1500.
    :param K: K-parameter for Elo rating updates.
    :param alpha: alpha parameter for calculating probabilities from Elo.
    :param calculate_W_mv: Function for calculating the victory multiplier.
    
    Runs through Elo from start to finish for set of games, assuming that we are starting from the beginning -
    i.e. the teams do not have pre-existing Elo ratings calculated from other games and thus all initial
    Elo ratings are set to 1500.
    """
    teams_final = teams.copy()
    previous_year = 2008
    
    for i in range(data.shape[0]):
        row = data.iloc[i, :]
        
        first = row['first_team']
        second = row['second_team']
        winner = row['winner']
        nrr = row['net_run_rate']
        home_country = row['venue_country']
        year = row['year']
        
        if year > previous_year:
            previous_year = year
            avg = np.mean(np.array(list(teams_final.values())))
            for ind in np.array(list(teams_final.keys())):
                mean_rev = mean_rev_const*(teams_final[ind]-avg)
                teams_final[ind] -= mean_rev
        
        if home_country == first:
            home = 'first'
        elif home_country == second:
            home = 'second'
        else:
            home = 'neutral'
        
        if first == winner:
            S_a = 1
            loser = second
        elif winner == 'tie':
            S_a = 0.5
            loser = 'tie'
        else:
            S_a = 0
            loser = first
        
        if winner != 'tie':
            W_mv = calculate_W_mv(nrr, teams_final[winner]-teams_final[loser])
        else:
            W_mv = 2.2*np.log(2)
        R_a_pr, R_b_pr = elo_step(teams_final[first], teams_final[second], S_a, K, W_mv, alpha, home, hga)
        
        teams_final[first] = R_a_pr
        teams_final[second] = R_b_pr
    
    return teams_final

# %%
def brier(data, teams, K, alpha=400, calculate_W_mv=calculate_W_mv_log, hga=0, mean_rev_const=0.3):
    """
    :param data: DataFrame of all games.
    :param elodict: Dictionary of teams and their final Elo scores.
    :param alpha: alpha parameter.
    Assumes simulation has already been completed and Elo ratings calculated. Cross entropy loss for Elo ratings.
    """
    score = 0
    teams_final = teams.copy()
    previous_year = 2008
    
    for i in range(data.shape[0]):
        row = data.iloc[i, :]
        
        first = row['first_team']
        second = row['second_team']
        winner = row['winner']
        nrr = row['net_run_rate']
        
        home_country = row['venue_country']
        
        year = row['year']
        
        if year > previous_year:
            previous_year = year
            avg = np.mean(np.array(list(teams_final.values())))
            for ind in np.array(list(teams_final.keys())):
                mean_rev = mean_rev_const*(teams_final[ind]-avg)
                teams_final[ind] -= mean_rev
        
        if home_country == first:
            home = 'first'
        elif home_country == second:
            home = 'second'
        else:
            home = 'neutral'
        
        
        if first == winner:
            S_a = 1
            loser = second
        elif winner == 'tie':
            S_a = 0.5
            loser = 'tie'
        else:
            S_a = 0
            loser = first
        
        if winner != 'tie':
            W_mv = calculate_W_mv(nrr, teams_final[winner]-teams_final[loser])
        else:
            W_mv = 2.2*np.log(2)
            
        E_a = prob_win_A(teams_final[first], teams_final[second], alpha, home, hga)
        E_b = 1 - E_a
        
        R_a_pr, R_b_pr = elo_step(teams_final[first], teams_final[second], S_a, K, W_mv, alpha, home, hga)
        
        brier_comp = (S_a - E_a)**2 + ((1-S_a) - E_b)**2
        score += brier_comp
        
        teams_final[first] = R_a_pr
        teams_final[second] = R_b_pr
        
        # brier_comp = (S_a - E_a)**2 + ((1-S_a) - E_b)**2
    
    score /= data.shape[0]
    
    return score

# %%
# def cross_entropy(data, elodict, alpha=400):
#     """
#     :param data: DataFrame of all games.
#     :param elodict: Dictionary of teams and their final Elo scores.
#     :param alpha: alpha parameter.
#     Assumes simulation has already been completed and Elo ratings calculated. Cross entropy loss for Elo ratings.
#     """
#     score = 0
    
#     for i in range(data.shape[0]):
#         row = data.iloc[i, :]
        
        
#         first, second, winner = row['first_team'], row['second_team'], row['winner']
        
#         elo1, elo2 = elodict[first], elodict[second]
#         E_a = prob_win_A(elo1, elo2, alpha)
#         E_b = 1 - E_a
        
#         if first == winner:
#             S_a = 1
#         elif winner == 'tie':
#             S_a = 0.5
#         else:
#             S_a = 0
        
#         # brier_comp = (S_a - E_a)**2 + ((1-S_a) - E_b)**2
#         cross_entropy_comp = -(S_a*np.log(E_a) + (1-S_a)*np.log(1-E_a))
#         score += cross_entropy_comp
    
#     score /= data.shape[0]
    
#     return score

# %%
def cross_entropy(data, teams, K, alpha=400, calculate_W_mv=calculate_W_mv_log, hga=0, mean_rev_const=0.3):
    """
    :param data: DataFrame of all games.
    :param elodict: Dictionary of teams and their final Elo scores.
    :param alpha: alpha parameter.
    Assumes simulation has already been completed and Elo ratings calculated. Cross entropy loss for Elo ratings.
    """
    score = 0
    teams_final = teams.copy()
    previous_year = 2008
    
    for i in range(data.shape[0]):
        row = data.iloc[i, :]
        
        first = row['first_team']
        second = row['second_team']
        winner = row['winner']
        nrr = row['net_run_rate']
        
        home_country = row['venue_country']
        year = row['year']
        
        if year > previous_year:
            previous_year = year
            avg = np.mean(np.array(list(teams_final.values())))
            for ind in np.array(list(teams_final.keys())):
                mean_rev = mean_rev_const*(teams_final[ind]-avg)
                teams_final[ind] -= mean_rev
        
        if home_country == first:
            home = 'first'
        elif home_country == second:
            home = 'second'
        else:
            home = 'neutral'
        
        
        if first == winner:
            S_a = 1
            loser = second
        elif winner == 'tie':
            S_a = 0.5
            loser = 'tie'
        else:
            S_a = 0
            loser = first
        
        if winner != 'tie':
            W_mv = calculate_W_mv(nrr, teams_final[winner]-teams_final[loser])
        else:
            W_mv = 2.2*np.log(2)
            
        E_a = prob_win_A(teams_final[first], teams_final[second], alpha, home, hga)
        E_b = 1 - E_a
        
        R_a_pr, R_b_pr = elo_step(teams_final[first], teams_final[second], S_a, K, W_mv, alpha, home, hga)
        
        cross_entropy_comp = -(S_a*np.log(E_a) + (1-S_a)*np.log(1-E_a))
        score += cross_entropy_comp
        
        teams_final[first] = R_a_pr
        teams_final[second] = R_b_pr
        
        # brier_comp = (S_a - E_a)**2 + ((1-S_a) - E_b)**2
    
    score /= data.shape[0]
    
    return score

# %%
# def correctness(data, elodict, alpha=400): # TODO: Fix this
#     """
#     :param data: DataFrame of all games.
#     :param elodict: Dictionary of teams and their final Elo scores.
#     :param alpha: alpha parameter.
#     Assumes simulation has already been completed and Elo ratings calculated. Correctness (i.e., what %
#     of games are predicted correctly) for Elo ratings.
#     """
#     score = 0
    
#     for i in range(data.shape[0]):
#         row = data.iloc[i, :]
        
        
#         first, second, winner = row['first_team'], row['second_team'], row['winner']
        
#         elo1, elo2 = elodict[first], elodict[second]
#         E_a = prob_win_A(elo1, elo2, alpha)
#         E_b = 1 - E_a
        
#         if E_a >= 0.5:
#             S_exp = 1
#         else:
#             S_exp = 0
        
#         if first == winner:
#             S_a = 1
#         elif winner == 'tie':
#             S_a = 0.5
#         else:
#             S_a = 0
        
#         if S_exp == S_a:
#             score += 1
    
#     score /= data.shape[0]
    
#     return score

# %%
def correctness(data, teams, K, alpha=400, calculate_W_mv=calculate_W_mv_log, hga=0, mean_rev_const=0.3):
    """
    :param data: DataFrame of all games.
    :param elodict: Dictionary of teams and their final Elo scores.
    :param alpha: alpha parameter.
    Assumes simulation has already been completed and Elo ratings calculated. Cross entropy loss for Elo ratings.
    """
    score = 0
    teams_final = teams.copy()
    previous_year = 2008
    
    for i in range(data.shape[0]):
        row = data.iloc[i, :]
        
        first = row['first_team']
        second = row['second_team']
        winner = row['winner']
        nrr = row['net_run_rate']
        
        home_country = row['venue_country']
        year = row['year']
        
        if year > previous_year:
            previous_year = year
            avg = np.mean(np.array(list(teams_final.values())))
            for ind in np.array(list(teams_final.keys())):
                mean_rev = mean_rev_const*(teams_final[ind]-avg)
                teams_final[ind] -= mean_rev
        
        if home_country == first:
            home = 'first'
        elif home_country == second:
            home = 'second'
        else:
            home = 'neutral'
        
        
        if first == winner:
            S_a = 1
            loser = second
        elif winner == 'tie':
            S_a = 0.5
            loser = 'tie'
        else:
            S_a = 0
            loser = first
        
        if winner != 'tie':
            W_mv = calculate_W_mv(nrr, teams_final[winner]-teams_final[loser])
        else:
            W_mv = 2.2*np.log(2)
            
        E_a = prob_win_A(teams_final[first], teams_final[second], alpha, home, hga)
        E_b = 1 - E_a
        
        if E_a >= 0.5:
            S_exp = 1
        else:
            S_exp = 0
        
        R_a_pr, R_b_pr = elo_step(teams_final[first], teams_final[second], S_a, K, W_mv, alpha, home, hga)
        
        # cross_entropy_comp = -(S_a*np.log(E_a) + (1-S_a)*np.log(1-E_a))
        if S_exp == S_a:
            score += 1
        
        teams_final[first] = R_a_pr
        teams_final[second] = R_b_pr
        
        # brier_comp = (S_a - E_a)**2 + ((1-S_a) - E_b)**2
    
    score /= data.shape[0]
    
    return score

# %%
# data.iloc[0, :]

# %%
def extract_cricket_summary(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Get teams and winner
    teams = data['info']['teams']
    
    winner = data['info']['outcome'].get('winner')
    
    if winner is None:
        match data['info']['outcome'].get('result'):
            case 'no result':
                winner = 'no result'
            case 'tie':
                winner = 'tie'
                
    if data['info']['outcome'].get('method') == 'Awarded':
        print('Haiiiii! We at ', file_path, '<3')
    
    date = data['info']['dates'][0]
    
    teams_np = np.array(teams)
    
    loser = teams_np[teams_np != winner][0]
    
    first = (data['info']['toss']['winner'] if data['info']['toss']['decision']=='bat' 
             else teams_np[teams_np != data['info']['toss']['winner']][0])
    second = teams_np[teams_np != first][0]
    
    # city = data['info']['city']
    venue = data['info']['venue']

    team_stats = {}

    for innings in data['innings']:
        team = innings['team']
        total_runs = 0
        legal_balls = 0

        for over in innings['overs']:
            for delivery in over['deliveries']:
                # Add runs
                total_runs += delivery['runs']['total']
                
                # Count legal balls only (not wides or no-balls)
                extras = delivery.get('extras', {})
                if 'wides' not in extras and 'noballs' not in extras:
                    legal_balls += 1

        overs = legal_balls // 6 + (legal_balls % 6) / 10
        team_stats[team] = {
            'runs': total_runs,
            'balls': legal_balls,
            'overs': round(overs, 1)
        }
    
    if winner == 'no result' or data['info']['outcome'].get('method') == 'Awarded':
        nrr = float('nan')
    
    elif winner == 'tie':
        nrr = abs((team_stats[first]['runs'] - team_stats[second]['runs'])/20)
    
    elif team_stats[second]['balls'] <= 120 and winner == second: # quickfix: Condition on balls instead of overs
        nrr = team_stats[winner]['runs']/team_stats[winner]['overs'] - team_stats[loser]['runs']/team_stats[loser]['overs']
    
    else:
        nrr = (team_stats[winner]['runs'] - team_stats[loser]['runs']) / 20
    
    if winner == 'no result' or data['info']['outcome'].get('method') == 'Awarded': # For our purposes, matches with no result do not matter for Elo rating updates
        return {
        'date': date,
        'winner': winner,
        # 'city': city,
        'venue': venue,
        'first_team': first,
        'second_team': second,
        'first_runs': float('nan'),
        'first_balls': float('nan'),
        'first_overs': float('nan'),
        'second_runs': float('nan'),
        'second_balls': float('nan'),
        'second_overs': float('nan'),
        'net_run_rate': nrr
    }
    
    return {
        'date': date,
        'winner': winner,
        # 'city': city,
        'venue': venue,
        'first_team': first,
        'second_team': second,
        'first_runs': team_stats[first]['runs'],
        'first_balls': team_stats[first]['balls'],
        'first_overs': team_stats[first]['overs'],
        'second_runs': team_stats[second]['runs'],
        'second_balls': team_stats[second]['balls'],
        'second_overs': team_stats[second]['overs'],
        'net_run_rate': nrr
    }

# %%
# Example usage
summary = extract_cricket_summary("ipl-data/335984.json")
# summary = extract_cricket_summary("data/1407719.json")
print(summary)
# Out:
# {'date': '2008-04-19', 'winner': 'Delhi Daredevils', 'venue': 'Feroz Shah Kotla', 'first_team': 'Rajasthan Royals', 'second_team': 'Delhi Daredevils', 'first_runs': 129, 'first_balls': 120, 'first_overs': 20.0, 'second_runs': 132, 'second_balls': 91, 'second_overs': 15.1, 'net_run_rate': 2.291721854304636}

# %%
def load_directory(directory):
    summaries = []

    for filename in os.listdir(directory):
        if filename.endswith('.json'):
            full_path = os.path.join(directory, filename)
            try:
                summary = extract_cricket_summary(full_path)
                if summary:
                    summaries.append(summary)
            except Exception as e:
                print(f"Error processing {filename}: {e}")

    return pd.DataFrame(summaries)

# %%
def calculate_nrr(winner, first, second, first_runs, first_overs, second_runs, second_overs):
    if winner == 'tie':
        nrr = abs((first_runs - second_runs)/20)
    elif second_overs <= 20 and winner == second:
        nrr = second_runs/second_overs - first_runs/first_overs
    elif winner == first:
        nrr = (first_runs - second_runs) / 20
    
    return nrr

# %%
# # afg = pd.read_csv('afghanistan-T20I-matches.csv')
# # print(afg['winner'])
# # afg['net_run_rate'] = afg[['winner', 'first_team', 'second_team', 'first_runs', 'first_overs', 'second_runs',
#                           'second_overs']].apply(lambda x: calculate_nrr(x['winner'], x['first_team'], x['second_team'],
#                                                                          x['first_runs'], x['first_overs'], x['second_runs'],
#                                                                          x['second_overs']), axis=1)
# # afg.head()

# %%
app_matches = pd.read_csv('appended-mlc-matches-2025.csv')
app_matches['net_run_rate'] = app_matches[['winner', 'first_team', 'second_team', 'first_runs', 'first_overs', 'second_runs',
                          'second_overs']].apply(lambda x: calculate_nrr(x['winner'], x['first_team'], x['second_team'],
                                                                         x['first_runs'], x['first_overs'], x['second_runs'],
                                                                         x['second_overs']), axis=1)
app_matches.head()
# Out:
#          date                  winner                     venue  \
# 0  2025-06-15       Texas Super Kings  Oakland Coliseum,Oakland
# 1  2025-06-16       Texas Super Kings  Oakland Coliseum,Oakland
# 2  2025-06-15  San Francisco Unicorns  Oakland Coliseum,Oakland
# 3  2025-06-17      Washington Freedom  Oakland Coliseum,Oakland
# 4  2025-06-18             MI New York  Oakland Coliseum,Oakland
#
#            first_team                second_team  first_runs  first_balls  \
# 0   Texas Super Kings  Los Angeles Knight Riders         181          120
# 1   Texas Super Kings              Seattle Orcas         153          120
# 2         MI New York     San Francisco Unicorns         182          120
# 3  Washington Freedom  Los Angeles Knight Riders         208          120
# 4       Seattle Orcas                MI New York         200          120
#
#    first_overs  second_runs  second_balls  second_overs  net_run_rate
# 0           20          124            99          17.1      2.850000
# 1           20           60            80          13.5      4.650000
# 2           20          188           110          19.1      0.742932
# 3           20           95            96          16.3      5.650000
# 4           20          203           114          19.0      0.684211

# %%
data = load_directory('mlc-data/')
data = pd.concat([data, app_matches], axis=0)
# data = pd.concat([data, afg], axis=0)
data = data.sort_values(by=['date'], ascending=True)
data.head()
# Out:
#          date                  winner                  venue  \
# 0  2023-07-13       Texas Super Kings  Grand Prairie Stadium
# 1  2023-07-14  San Francisco Unicorns  Grand Prairie Stadium
# 2  2023-07-14           Seattle Orcas  Grand Prairie Stadium
# 3  2023-07-15           Seattle Orcas  Grand Prairie Stadium
# 4  2023-07-16      Washington Freedom  Grand Prairie Stadium
#
#                first_team                second_team  first_runs  first_balls  \
# 0       Texas Super Kings  Los Angeles Knight Riders       181.0        120.0
# 1  San Francisco Unicorns                MI New York       215.0        120.0
# 2      Washington Freedom              Seattle Orcas       144.0        120.0
# 3           Seattle Orcas     San Francisco Unicorns       177.0        120.0
# 4      Washington Freedom          Texas Super Kings       163.0        120.0
#
#    first_overs  second_runs  second_balls  second_overs  net_run_rate
# 0         20.0        112.0          84.0          14.0      3.450000
# 1         20.0        193.0         120.0          20.0      1.100000
# 2         20.0        148.0         118.0          19.4      0.428866
# 3         20.0        142.0         107.0          17.5      1.750000
# 4         20.0        157.0         120.0          20.0      0.300000

# %%
data.shape
# Out:
# (52, 12)

# %%
data['date'] = pd.DatetimeIndex(data['date'])
# data['date']

# %%
data['year'] = data['date'].map(lambda x: x.year)
# data['year']

# %%
data.iloc[-1, :]
# Out:
# date                      2025-06-20 00:00:00
# winner                 San Francisco Unicorns
# venue           Grand Prairie Stadium, Dallas
# first_team                  Texas Super Kings
# second_team            San Francisco Unicorns
# first_runs                              198.0
# first_balls                             120.0
# first_overs                              20.0
# second_runs                             202.0
# second_balls                             91.0
# second_overs                             16.1
# net_run_rate                         2.646584
# year                                     2025
# Name: 5, dtype: object

# %%
data = data[data['winner'] != 'no result']
data = data[~data['net_run_rate'].isna()]
data.shape
# Out:
# (51, 13)

# %%
# data.iloc[-1, :]

# %%
grounds = np.unique(data['venue'].values)
grounds
# Out:
# array(['Church Street Park, Morrisville', 'Grand Prairie Stadium',
#        'Grand Prairie Stadium, Dallas', 'Oakland Coliseum,Oakland'],
#       dtype=object)

# %%
grounds_to_home = {
    'Church Street Park, Morrisville': 'neutral',
    'Grand Prairie Stadium': 'Texas Super Kings',
    'Grand Prairie Stadium, Dallas': 'Texas Super Kings',
# 6       0.850000  2023       Texas Super Kings
# 7       1.050000  2023       Texas Super Kings
# 8       1.029006  2023                 neutral
# 9       1.650000  2023                 neutral
# 10      1.500000  2023                 neutral
# 12      2.522876  2023                 neutral
# 11      0.662304  2023                 neutral
# 13      0.455236  2023                 neutral
# 14      0.456250  2023                 neutral
# 15      0.800000  2023       Texas Super Kings
# 16      2.166667  2023       Texas Super Kings
# 17      0.626316  2023       Texas Super Kings
# 18      2.350000  2023       Texas Super Kings
# 19      2.162451  2024                 neutral
# 20      0.600000  2024       Texas Super Kings
# 21     -0.267568  2024                 neutral
# 22      2.671053  2024       Texas Super Kings
# 24      0.266667  2024       Texas Super Kings
# 25      2.982857  2024                 neutral
# 26      0.586269  2024       Texas Super Kings
# 27      1.114130  2024                 neutral
# 28      0.750000  2024       Texas Super Kings
# 29      1.150000  2024                 neutral
# 30      4.700000  2024       Texas Super Kings
# 31      0.386911  2024                 neutral
# 32      0.150000  2024       Texas Super Kings
# 33      2.100000  2024       Texas Super Kings
# 34      3.385915  2024       Texas Super Kings
# 35      1.076070  2024       Texas Super Kings
# 36      1.836406  2024       Texas Super Kings
# 37      1.850000  2024       Texas Super Kings
# 38      0.975683  2024       Texas Super Kings
# 39      2.106983  2024       Texas Super Kings
# 40      0.500000  2024       Texas Super Kings
# 41      4.800000  2024       Texas Super Kings
# 42      6.150000  2025  San Francisco Unicorns
# 43      0.150000  2025  San Francisco Unicorns
# 44      1.600000  2025  San Francisco Unicorns
# 45      3.953008  2025  San Francisco Unicorns
# 0       2.850000  2025  San Francisco Unicorns
# 2       0.742932  2025  San Francisco Unicorns
# 1       4.650000  2025  San Francisco Unicorns
# 3       5.650000  2025  San Francisco Unicorns
# 4       0.684211  2025  San Francisco Unicorns
# 5       2.646584  2025       Texas Super Kings

# %%
# np.unique(data['venue_country'].values)

# %%
# data['venue_country'] = data['venue_country'].map(lambda x: 'West Indies' if x in ['Antigua and Barbuda', 'Grenada', 'Guyana', 'Jamaica',
#                                                                    'Saint Lucia', 'Saint Vincent and the Grenadines', 'Barbados',
#                                                                    'Trinidad and Tobago'] else x)
# data['venue_country'] = data['venue_country'].map(lambda x: 'Scotland' if x == 'Scotland (United Kingdom)' else
#                                                  ('Wales' if x == 'Wales (United Kingdom)' else
#                                                  ('Northern Ireland' if x == 'Northern Ireland (United Kingdom)' else x)))
# data['venue_country']

# %%
# data = data.replace({'Rising Pune Supergiants':'Rising Pune Supergiant',
#                                                 'Royal Challengers Bangalore': 'Royal Challengers Bengaluru',
#                     'Delhi Daredevils':'Delhi Capitals',
#                     'Kings XI Punjab': 'Punjab Kings',
#                     'Deccan Chargers': 'Sunrisers Hyderabad'})

# %%
teams = np.unique(np.append(data['first_team'].values, data['second_team'].values))
teams
# Out:
# array(['Los Angeles Knight Riders', 'MI New York',
#        'San Francisco Unicorns', 'Seattle Orcas', 'Texas Super Kings',
#        'Washington Freedom'], dtype=object)

# %%
np.unique(data['venue_country'].values)
# Out:
# array(['San Francisco Unicorns', 'Texas Super Kings', 'neutral'],
#       dtype=object)

# %%
np.unique(np.append(data['first_team'].values, data['second_team'].values))
# Out:
# array(['Los Angeles Knight Riders', 'MI New York',
#        'San Francisco Unicorns', 'Seattle Orcas', 'Texas Super Kings',
#        'Washington Freedom'], dtype=object)

# %%
sample_Ks = np.arange(7, 120, 0.5)
sample_alphas = np.arange(100, 800, 1)

# %%
def crossent_cond(params):
    K, alpha, hga, mean_rev_const = params
    ce_score = cross_entropy(data, intl_elos, K=K, alpha=alpha, hga=hga, mean_rev_const=mean_rev_const)
    return ce_score

# %%
intl_elos = {key: 1500 for key in teams}
intl_elos # At start
# Out:
# {'Los Angeles Knight Riders': 1500,
#  'MI New York': 1500,
#  'San Francisco Unicorns': 1500,
#  'Seattle Orcas': 1500,
#  'Texas Super Kings': 1500,
#  'Washington Freedom': 1500}

# %%
# intl_elos.values()

# %%
x0 = [100, 400, 80, 0.3]
bounds = [(15, 150), (200, 600), (0, 1000), (0, 0.65)]
res = opt.minimize(crossent_cond, x0, bounds=bounds)
K_opt, alpha_opt, hga_opt, mrc_opt = res.x
log_err = res.fun
K_opt, alpha_opt, hga_opt, mrc_opt, log_err
# Out:
# (106.48059306482318, 406.58672146000106, 0.0, 0.65, 0.655343237670208)

# %%
# Get optimized results from above later once you're done fixing above!
# K_opt, alpha_opt, hga_opt = 80.3223654592129, 502.2928412067084, 72.45113954192632

# %%
# K = 69.5
# alpha = 509
# K_opt = 38
elo_sample_dict = generate_elo_ratings(data, intl_elos, K=K_opt, alpha=alpha_opt, hga=hga_opt, mean_rev_const=mrc_opt)
dict(sorted(elo_sample_dict.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'San Francisco Unicorns': 1709.0002098431673,
#  'Washington Freedom': 1587.4765389775193,
#  'Texas Super Kings': 1551.4138637064439,
#  'MI New York': 1486.3645770041378,
#  'Los Angeles Knight Riders': 1339.5259362580473,
#  'Seattle Orcas': 1326.2188742106841}

# %%
elo_df = pd.DataFrame(elo_sample_dict, index=[0]).T
elo_df = elo_df.rename({0:'elo'}, axis=1)
elo_df
# Out:
#                                    elo
# Los Angeles Knight Riders  1339.525936
# MI New York                1486.364577
# San Francisco Unicorns     1709.000210
# Seattle Orcas              1326.218874
# Texas Super Kings          1551.413864
# Washington Freedom         1587.476539

# %%
elo_df.to_csv('mlc_init_elos-21-6-25.csv')

# %%
data.to_csv('past_matches_mlc_2025.csv')

# %%
# prob_win_country_A(elo_sample_dict, 'Nepal', 'Netherlands', venue_country='Scotland', alpha=alpha_opt, hga=hga_opt)

# %%
brier_score = brier(data, intl_elos, K=K_opt, alpha=alpha_opt, hga=hga_opt, mean_rev_const=mrc_opt)
brier_score
# Out:
# 0.459613206015509

# %%
cross_ent_loss = cross_entropy(data, intl_elos, K=K_opt, alpha=alpha_opt, hga=hga_opt, mean_rev_const=mrc_opt)
cross_ent_loss
# Out:
# 0.655343237670208

# %%
correct = correctness(data, intl_elos, K=K_opt, alpha=alpha_opt, hga=hga_opt, mean_rev_const=mrc_opt)
correct
# Out:
# 0.6078431372549019

# %%
K_alpha = np.array(np.meshgrid(sample_Ks, sample_alphas)).T.reshape(-1, 2)
K_alpha
# Out:
# array([[  7. , 100. ],
#        [  7. , 101. ],
#        [  7. , 102. ],
#        ...,
#        [119.5, 797. ],
#        [119.5, 798. ],
#        [119.5, 799. ]])

# %%
plt.hist(data['net_run_rate'], bins=50)
plt.xlim(0, 15)
plt.grid()

# %%
# def generate_elo_ratings_trends(data, teams, K, alpha=400, calculate_W_mv=calculate_W_mv_log):
#     """
#     :param data: DataFrame of games played.
#     :param teams: Dictionary of all teams with respective elo rating scores. At the start, all teams' Elo ratings 
#     will be set to 1500.
#     :param K: K-parameter for Elo rating updates.
#     :param alpha: alpha parameter for calculating probabilities from Elo.
#     :param calculate_W_mv: Function for calculating the victory multiplier.
    
#     Runs through Elo from start to finish for set of games, assuming that we are starting from the beginning -
#     i.e. the teams do not have pre-existing Elo ratings calculated from other games and thus all initial
#     Elo ratings are set to 1500.
#     """
#     teams_final = teams.copy()
#     team_trends = {key: [1500] for key in list(teams.keys())}
    
#     for i in range(data.shape[0]):
#         row = data.iloc[i, :]
        
#         first = row['first_team']
#         second = row['second_team']
#         winner = row['winner']
#         nrr = row['net_run_rate']
        
#         if first == winner:
#             S_a = 1
#             loser = second
#         elif winner == 'tie':
#             S_a = 0.5
#             loser = 'tie'
#         else:
#             S_a = 0
#             loser = first
        
#         if winner != 'tie':
#             W_mv = calculate_W_mv(nrr, teams_final[winner]-teams_final[loser])
#         else:
#             W_mv = 2.2*np.log(2)
#         R_a_pr, R_b_pr = elo_step(teams_final[first], teams_final[second], S_a, K, W_mv, alpha)
        
#         team_trends[first].append(R_a_pr)
#         team_trends[second].append(R_b_pr)
        
#         teams_final[first] = R_a_pr
#         teams_final[second] = R_b_pr
    
#     return teams_final, team_trends

# %%
def generate_elo_ratings_trends(data, teams, K, alpha=400, calculate_W_mv=calculate_W_mv_log, hga=0, mean_rev_const=0.3):
    """
    :param data: DataFrame of games played.
    :param teams: Dictionary of all teams with respective elo rating scores. At the start, all teams' Elo ratings 
    will be set to 1500.
    :param K: K-parameter for Elo rating updates.
    :param alpha: alpha parameter for calculating probabilities from Elo.
    :param calculate_W_mv: Function for calculating the victory multiplier.
    
    Runs through Elo from start to finish for set of games, assuming that we are starting from the beginning -
    i.e. the teams do not have pre-existing Elo ratings calculated from other games and thus all initial
    Elo ratings are set to 1500.
    """
    teams_final = teams.copy()
    team_trends = {key: [1500] for key in list(teams.keys())}
    previous_year = 2008
    
    for i in range(data.shape[0]):
        row = data.iloc[i, :]
        
        first = row['first_team']
        second = row['second_team']
        winner = row['winner']
        nrr = row['net_run_rate']
        home_country = row['venue_country']
        year = row['year']
        
        if year > previous_year:
            previous_year = year
            avg = np.mean(np.array(list(teams_final.values())))
            for ind in np.array(list(teams_final.keys())):
                mean_rev = mean_rev_const*(teams_final[ind]-avg)
                teams_final[ind] -= mean_rev
        
        if home_country == first:
            home = 'first'
        elif home_country == second:
            home = 'second'
        else:
            home = 'neutral'
        
        if first == winner:
            S_a = 1
            loser = second
        elif winner == 'tie':
            S_a = 0.5
            loser = 'tie'
        else:
            S_a = 0
            loser = first
        
        if winner != 'tie':
            W_mv = calculate_W_mv(nrr, teams_final[winner]-teams_final[loser])
        else:
            W_mv = 2.2*np.log(2)
        R_a_pr, R_b_pr = elo_step(teams_final[first], teams_final[second], S_a, K, W_mv, alpha, home, hga)
        
        team_trends[first].append(R_a_pr)
        team_trends[second].append(R_b_pr)
        
        teams_final[first] = R_a_pr
        teams_final[second] = R_b_pr
    
    return teams_final, team_trends

# %%
# intl_elos

# %%
_, team_trends = generate_elo_ratings_trends(data, intl_elos, K=K_opt, alpha=alpha_opt, hga=hga_opt, mean_rev_const=mrc_opt)

# %%
# dict(sorted(elos.items(), key=lambda item: item[1], reverse=True))

# %%
team_trends['San Francisco Unicorns'][-1]
# Out:
# 1709.0002098431673

# %%
plt.plot(team_trends['Texas Super Kings'])
plt.xlabel('Number of matches played')
plt.ylabel('Elo rating')
# Out:
# Text(0, 0.5, 'Elo rating')

# %%
np.max(team_trends['MI New York'])
# Out:
# 1675.983323241591

# %%
data[data['winner'] == 'tie'].shape[0] / data.shape[0]
# Out:
# 0.0

# %%
# def elodiffs_v_nrrs(data, teams, K, alpha=400, calculate_W_mv=lambda x: 1):
#     """
#     :param data: DataFrame of games played.
#     :param teams: Dictionary of all teams with respective elo rating scores. At the start, all teams' Elo ratings 
#     will be set to 1500.
#     :param K: K-parameter for Elo rating updates.
#     :param alpha: alpha parameter for calculating probabilities from Elo.
#     :param calculate_W_mv: Function for calculating the victory multiplier.
    
#     Runs through Elo from start to finish for set of games, assuming that we are starting from the beginning -
#     i.e. the teams do not have pre-existing Elo ratings calculated from other games and thus all initial
#     Elo ratings are set to 1500.
#     """
#     teams_final = teams.copy()
#     # team_trends = {key: [1500] for key in list(teams.keys())}
#     diffs = []
#     nrrs = []
#     it = 0
    
#     for i in range(data.shape[0]):
#         row = data.iloc[i, :]
        
#         first = row['first_team']
#         second = row['second_team']
#         winner = row['winner']
#         nrr = row['net_run_rate']
        
#         if first == winner:
#             S_a = 1
#         elif winner == 'tie':
#             S_a = 0.5
#         else:
#             S_a = 0
            
#         if it > 0:
#             diffs.append(abs(teams_final[first] - teams_final[second]))
#             nrrs.append(abs(nrr))
        
#         W_mv = calculate_W_mv(nrr)
#         R_a_pr, R_b_pr = elo_step(teams_final[first], teams_final[second], S_a, K, W_mv, alpha)
        
#         teams_final[first] = R_a_pr
#         teams_final[second] = R_b_pr
        
#         if it == 0:
#             it += 1
    
#     return np.array([diffs]).T, np.array(nrrs).T

# %%
# diffs, nrrs = elodiffs_v_nrrs(data, intl_elos, 45.5, alpha=214)

# %%
# diffs, nrrs, diffs.shape, nrrs.shape

# %%
# plt.scatter(diffs, nrrs)

# %%
# reg = lm.LinearRegression()
# reg.fit(diffs, nrrs)
# reg.coef_, reg.intercept_

# %%
# r_regression(diffs, nrrs)

# %%
# expected_nrrs = reg.coef_[0]*diffs + reg.intercept_
# mse = np.sum((expected_nrrs-nrrs)**2) / nrrs.shape[0]
# mse
